# %% [markdown]
# <a href="https://colab.research.google.com/github/omniaghazy/learn-sklearn/blob/main/9_Dataset_loading_utilities.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sklearn

# %%
sklearn.__version__
# Out:
# '1.6.1'

# %% [markdown]
# # **Datasets**

# %%
from sklearn.utils import Bunch

# %%
bun = Bunch(
    name = "omnia"
)

# %%
bun.name
# Out:
# 'omnia'

# %%
bun["name"]
# Out:
# 'omnia'

# %%
bun.age = 24

# %%
bun.items()
# Out:
# dict_items([('name', 'omnia'), ('age', 24)])

# %%
type(bun)
# Out:
# sklearn.utils._bunch.Bunch

# %%
bun["school"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1946/3144748545.py in <cell line: 0>()
# ----> 1 bun["school"]
#
# /usr/local/lib/python3.13/dist-packages/sklearn/utils/_bunch.py in __getitem__(self, key)
#      40                 FutureWarning,
#      41             )
# ---> 42         return super().__getitem__(key)
#      43
#      44     def _set_deprecated(self, value, *, new_key, deprecated_key, warning_message):
#
# KeyError: 'school'

# %%
bun.get("school" ,"nothing")
# Out:
# 'nothing'

# %%
from sklearn.datasets import load_iris

# %%
iris = load_iris()
# iris            #bunch

# %%
x = iris.data

# %%
y = iris.target

# %%
iris.DESCR
# Out:
# '.. _iris_dataset:\n\nIris plants dataset\n--------------------\n\n**Data Set Characteristics:**\n\n:Number of Instances: 150 (50 in each of three classes)\n:Number of Attributes: 4 numeric, predictive attributes and the class\n:Attribute Information:\n    - sepal length in cm\n    - sepal width in cm\n    - petal length in cm\n    - petal width in cm\n    - class:\n            - Iris-Setosa\n            - Iris-Versicolour\n            - Iris-Virginica\n\n:Summary Statistics:\n\n============== ==== ==== ======= ===== ====================\n                Min  Max   Mean    SD   Class Correlation\n============== ==== ==== ======= ===== ====================\nsepal length:   4.3  7.9   5.84   0.83    0.7826\nsepal width:    2.0  4.4   3.05   0.43   -0.4194\npetal length:   1.0  6.9   3.76   1.76    0.9490  (high!)\npetal width:    0.1  2.5   1.20   0.76    0.9565  (high!)\n============== ==== ==== ======= ===== ====================\n\n:Missing Attribute Values: None\n:Class Distribution
# ...

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
iris.data_module
# Out:
# 'sklearn.datasets.data'

# %%
iris.filename
# Out:
# 'iris.csv'

# %% [markdown]
# # **Session Online**

# %%
dic = {
    "name" : "Omnia" ,
    "age " :23
}

# %%
dic["name"]
# Out:
# 'Omnia'

# %%
import sklearn

# %%
from sklearn.utils import Bunch

# %%
bun = Bunch(age = 23)

# %%
bun = Bunch(name = "Omnia")

# %%
bun.name
# Out:
# 'Omnia'

# %%
bun["name"]
# Out:
# 'Omnia'

# %%
bun
# Out:
# {'name': 'Omnia'}

# %%
bun.age =23

# %%
bun
# Out:
# {'name': 'Omnia', 'age': 23}

# %%
bun.items()
# Out:
# dict_items([('name', 'Omnia'), ('age', 23)])

# %%
from sklearn.datasets import load_iris

# %%
iris = load_iris()

# %%
type(iris)
# Out:
# sklearn.utils._bunch.Bunch

# %%
x=iris.data

# %%
y=iris.target

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
iris.DESCR
# Out:
# '.. _iris_dataset:\n\nIris plants dataset\n--------------------\n\n**Data Set Characteristics:**\n\n:Number of Instances: 150 (50 in each of three classes)\n:Number of Attributes: 4 numeric, predictive attributes and the class\n:Attribute Information:\n    - sepal length in cm\n    - sepal width in cm\n    - petal length in cm\n    - petal width in cm\n    - class:\n            - Iris-Setosa\n            - Iris-Versicolour\n            - Iris-Virginica\n\n:Summary Statistics:\n\n============== ==== ==== ======= ===== ====================\n                Min  Max   Mean    SD   Class Correlation\n============== ==== ==== ======= ===== ====================\nsepal length:   4.3  7.9   5.84   0.83    0.7826\nsepal width:    2.0  4.4   3.05   0.43   -0.4194\npetal length:   1.0  6.9   3.76   1.76    0.9490  (high!)\npetal width:    0.1  2.5   1.20   0.76    0.9565  (high!)\n============== ==== ==== ======= ===== ====================\n\n:Missing Attribute Values: None\n:Class Distribution
# ...
