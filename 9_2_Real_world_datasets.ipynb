# %% [markdown]
# <a href="https://colab.research.google.com/github/omniaghazy/learn-sklearn/blob/main/9_2_Real_world_datasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # fetch_olivetti_faces

# %% [markdown]
# # fetch_20newsgroups

# %% [markdown]
# # fetch_20newsgroups_vectorized

# %% [markdown]
# # fetch_lfw_people

# %% [markdown]
# # fetch_lfw_pairs

# %% [markdown]
# # fetch_covtype

# %% [markdown]
# # fetch_rcv1

# %% [markdown]
# # fetch_kddcup99

# %% [markdown]
# # fetch_california_housing

# %% [markdown]
# # fetch_species_distributions
